# %%
url = 'https://public-api.adsbexchange.com/VirtualRadar/AircraftList.json'
r = requests.get(url)
data = r.json()

for i in range(0, len(data['acList'])):
    print (data['acList'][i]['Cou'], data['acList'][i]['Icao'], data['acList'][i]['Alt'])
# Out:
# NATO 477FF3 4600
# Germany 3D1128 3112
# Bermuda 424256 32975
# Indonesia 8A044B 8525
# Belgium 44CCC5 150
# Qatar 06A144 18625
# United Kingdom 407687 450
# China 780D5A 26600
# Hungary 471F61 175
# Qatar 06A1B9 39000
# China 780CB9 36000
# Austria 440019 37000
# Bermuda 424576 34000
# Portugal 49131A 5100
# United Kingdom 406674 825
# United Kingdom 402F2F 1000
# South Korea 71BD14 1725
# Spain 345593 10525
# Unknown or unassigned country 298EF4 1300
# Libya 018090 32975
# United Kingdom 4042BE 1100
# United Kingdom 40317C 3100
# Italy 31DD1A 1875
# United Kingdom 400B17 8232
# Taiwan 8990B5 2850
# China 780374 14975
# Indonesia 8A0637 24900
# Austria 44064B 1575
# Chile E80449 3725
# Austria 440154 2000
# Germany 3C4DCE 20175
# United Arab Emirates 896488 1400
# Tajikistan 515309 3525
# France 392AE9 24200
# United Kingdom 406D2C 150
# United States ADDE49 2800
# Japan 851CA8 3475
# United States AAEB59 10775
# Germany 3FF00D 3000
# Ireland 4CA898 37000
# Portugal 4951D4 1675
# ...
